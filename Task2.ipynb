# %%
"""
Read file into texts and calls.
It's ok if you don't understand how to read files
"""
import csv
with open('texts.csv', 'r') as f:
    reader = csv.reader(f)
    texts = list(reader)

with open('calls.csv', 'r') as f:
    reader = csv.reader(f)
    calls = list(reader)

"""
TASK 2: Which telephone number spent the longest time on the phone
during the period? Don't forget that time spent answering a call is
also time spent on the phone.
Print a message:
"<telephone number> spent the longest time, <total time> seconds, on the phone during 
September 2016.".
"""
max_call_duration = 0
max_call_number = ""
for each_line in calls: 
# check if call duration is longer than last record max_call_duration
    if int(each_line[3]) > int(max_call_duration): 
        max_call_duration = int(each_line[3])
        max_call_number = each_line[0]


print("{} <telephone number> spent the longest time, {} <total time> seconds, on the phone during September 2016.".format(max_call_number,max_call_duration))
# Out:
# 89071 50880 <telephone number> spent the longest time, 4617 <total time> seconds, on the phone during September 2016.

# %%
callers = {}

# %%
calls
# Out:
# [['78130 00821', '98453 94494', '01-09-2016 06:01:12', '186'],
#  ['78298 91466', '(022)28952819', '01-09-2016 06:01:59', '2093'],
#  ['97424 22395', '(022)47410783', '01-09-2016 06:03:51', '1975'],
#  ['93427 40118', '(080)33118033', '01-09-2016 06:11:23', '1156'],
#  ['90087 42537', '(080)35121497', '01-09-2016 06:17:26', '573'],
#  ['97427 87999', '(04344)322628', '01-09-2016 06:19:28', '2751'],
#  ['(080)45291968', '90365 06212', '01-09-2016 06:30:36', '9'],
#  ['78132 18081', '77956 90632', '01-09-2016 06:39:03', '3043'],
#  ['98453 46196', '94005 06213', '01-09-2016 06:40:20', '2457'],
#  ['78290 99865', '89071 31755', '01-09-2016 06:46:56', '9'],
#  ['(04344)228249', '(080)43901222', '01-09-2016 06:50:04', '2329'],
#  ['(080)62164823', '74066 93594', '01-09-2016 06:52:07', '300'],
#  ['(0821)6141380', '90366 69257', '01-09-2016 06:54:44', '2147'],
#  ['98446 66723', '83019 53227', '01-09-2016 06:56:16', '129'],
#  ['90088 09624', '93434 31551', '01-09-2016 06:57:44', '133'],
# ...

# %%
for each_line in calls:
    if each_line[0] not in callers:
        callers[each_line[0]] = int(each_line[3])
    else:
        callers[each_line[0]] += int(each_line[3])
        
    if each_line[1] not in callers:
        callers[each_line[1]] = int(each_line[3])
    else:
        callers[each_line[1]] += int(each_line[3])

# %%
callers
# Out:
# {'78130 00821': 26368,
#  '98453 94494': 26368,
#  '78298 91466': 42915,
#  '(022)28952819': 28474,
#  '97424 22395': 36667,
#  '(022)47410783': 33915,
#  '93427 40118': 6610,
#  '(080)33118033': 6610,
#  '90087 42537': 38792,
#  '(080)35121497': 61320,
#  '97427 87999': 28464,
#  '(04344)322628': 44953,
#  '(080)45291968': 75085,
#  '90365 06212': 31460,
#  '78132 18081': 15653,
#  '77956 90632': 38083,
#  '98453 46196': 33976,
#  '94005 06213': 10158,
#  '78290 99865': 17798,
#  '89071 31755': 17798,
#  '(04344)228249': 41771,
#  '(080)43901222': 17953,
#  '(080)62164823': 80264,
#  '74066 93594': 36622,
#  '(0821)6141380': 42053,
#  '90366 69257': 40935,
#  '98446 66723': 24396,
#  '83019 53227': 11969,
#  '90088 09624': 59757,
#  '93434 31551': 21704,
#  '93427 56500': 39716,
#  '98447 12671': 18088,
#  '(040)26738737': 30438,
#  '90194 00845': 34928,
#  '(080)67362492': 18596,
#  '(04344)316423': 18596,
#  '90192 87313': 27225,
#  '(080)33251027': 90456,
# ...

# %%
#initial code which increments ONLY callers' call times

# %%
print(max(callers.items(),key = lambda i : i[1]))

# %%
#after modifying code to also increment the receiver numbers' call times

# %%
print(max(callers.items(),key = lambda i : i[1]))
# Out:
# ('(080)33251027', 90456)

# %%
#from collections import OrderedDict

# %%
callers_ascending = sorted(callers, key=callers.get)

# %%
callers_ascending
# Out:
# ['97392 29513',
#  '97381 67759',
#  '(040)20512985',
#  '1404368883',
#  '98459 44682',
#  '95269 55869',
#  '93439 85886',
#  '98454 59941',
#  '95267 64394',
#  '97443 06352',
#  '(080)63559298',
#  '83040 21802',
#  '78993 92058',
#  '(080)63442225',
#  '99613 05278',
#  '98448 72117',
#  '97420 63582',
#  '81529 57063',
#  '(04344)212961',
#  '94486 48123',
#  '78290 30467',
#  '90365 82019',
#  '98447 81877',
#  '(0821)3774599',
#  '93431 90470',
#  '(0824)2321654',
#  '(080)22748361',
#  '(080)26008340',
#  '89076 36757',
#  '98447 63400',
#  '1408409918',
#  '78291 94593',
#  '97426 78238',
#  '93436 09781',
#  '1408672243',
#  '97395 95120',
#  '94490 65627',
#  '99617 74886',
#  '1409421631',
#  '90086 21082',
#  '1404073047',
#  '(022)32517986',
#  '(0471)2171438',
#  '87144 55014',
#  '70121 77245',
#  '84319 42810',
#  '(040)30429041',
#  '(080)39169481',
#  '83013 85044',
#  '1403579926',
#  '1403072432',
#  '93435 31225',
#  '87141 37314',
#  '97404 30456',
# ...

# %%
for kv_pairs in callers_ascending:
    print(kv_pairs, callers[kv_pairs])
# Out:
# 97392 29513 10
# 97381 67759 10
# (040)20512985 13
# 1404368883 23
# 98459 44682 26
# 95269 55869 34
# 93439 85886 35
# 98454 59941 40
# 95267 64394 44
# 97443 06352 45
# (080)63559298 46
# 83040 21802 46
# 78993 92058 47
# (080)63442225 49
# 99613 05278 50
# 98448 72117 54
# 97420 63582 55
# 81529 57063 56
# (04344)212961 57
# 94486 48123 64
# 78290 30467 66
# 90365 82019 71
# 98447 81877 73
# (0821)3774599 79
# 93431 90470 90
# (0824)2321654 93
# (080)22748361 100
# (080)26008340 102
# 89076 36757 138
# 98447 63400 166
# 1408409918 176
# 78291 94593 201
# 97426 78238 216
# 93436 09781 221
# 1408672243 244
# 97395 95120 291
# 94490 65627 291
# 99617 74886 301
# 1409421631 443
# 90086 21082 443
# 1404073047 471
# (022)32517986 505
# (0471)2171438 535
# 87144 55014 576
# 70121 77245 578
# 84319 42810 580
# (040)30429041 584
# (080)39169481 584
# 83013 85044 637
# 1403579926 667
# 1403072432 704
# 93435 31225 756
# 87141 37314 756
# 97404 30456 790
# (040)25325254 790
# ...

# %%
callers_descending = sorted(callers, key=callers.get, reverse=True)

# %%
for kv_pairs in callers_descending:
    print(kv_pairs, callers[kv_pairs])
# Out:
# (080)33251027 90456
# 97380 60551 84209
# (080)62164823 80264
# 99001 95783 78991
# (080)45291968 75085
# (080)47459867 71836
# (080)43562014 68994
# (080)46304537 65877
# (022)38214945 65739
# (080)25863765 65559
# (080)35121497 61320
# 78295 48262 59822
# 90088 09624 59757
# 70121 27677 53779
# 94482 95223 53544
# 94480 64700 52701
# (080)34121098 52613
# 97385 70012 51592
# 97447 92655 51277
# 98454 90038 48159
# 81510 47188 47654
# (0471)2953539 47588
# 98440 65896 47579
# 94005 20878 47258
# 93432 65750 46945
# 97429 02055 45865
# 92411 96415 45037
# (04344)322628 44953
# 95267 70383 44582
# (080)43685310 44506
# 99612 41256 44448
# 97406 06245 43582
# 92414 22596 43338
# (080)20123809 42986
# 78298 91466 42915
# 99007 06998 42760
# 90355 10919 42191
# 90368 72970 42161
# (0821)6141380 42053
# (04344)228249 41771
# 90366 69257 40935
# 99004 86250 40674
# 93427 56500 39716
# 81524 55552 39503
# 98446 78140 39435
# 97403 49292 39326
# 97399 92703 38810
# 90087 42537 38792
# ...
