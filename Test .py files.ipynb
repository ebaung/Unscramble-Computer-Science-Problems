# %%
# !python Task0.py
# Out:
# First record of texts, 97424 22395 <incoming number> texts 90365 06212 <answering number> at time 01-09-2016 06:03:22 <time>
#  Last record of calls, 98447 62998 <incoming number> calls (080)46304537 <answering number> at time 30-09-2016 23:57:15 <time>, lasting 2151<during> seconds

# %%
# !python Task1.py
# Out:
# Altogether, there are 570<count> different telephone numbers in the records of the 2 csv files texts.csv and calls.csv.
#
# The 570 unique telephone numbers are:
#
# (1, '(011)21017178')
# (2, '(011)47486239')
# (3, '(011)68486606')
# (4, '(022)21884607')
# (5, '(022)22288051')
# (6, '(022)28765220')
# (7, '(022)28952819')
# (8, '(022)29303640')
# (9, '(022)30044349')
# (10, '(022)32517986')
# (11, '(022)34715405')
# (12, '(022)37572285')
# (13, '(022)38214945')
# (14, '(022)39006198')
# (15, '(022)40840621')
# (16, '(022)44927512')
# (17, '(022)45444747')
# (18, '(022)46574732')
# (19, '(022)47410783')
# (20, '(022)60273083')
# (21, '(022)62120910')
# (22, '(022)65548497')
# (23, '(022)66911540')
# (24, '(022)68535788')
# (25, '(022)69042431')
# (26, '(033)25441815')
# (27, '(040)20512985')
# (28, '(040)25325254')
# (29, '(040)26738737')
# (30, '(040)30429041')
# (31, '(040)34008657')
# (32, '(040)36649724')
# (33, '(040)66729318')
# (34, '(040)69695864')
# (35, '(04344)211113')
# ...

# %%
# !python Task2.py
# Out:
# 89071 50880 <telephone number> spent the longest time, 4617 <total time> seconds, on the phone during September 2016.

# %%
# !python Task3.py
# Out:
# PART A
# The numbers called by people in Bangalore have codes:
#
# Fixed lines:
# (011)
# (022)
# (033)
# (040)
# (04344)
# (044)
# (04546)
# (0471)
# (080)
# (0821)
# (08214175)
# (0824)
#
# Mobile numbers (4 digit prefixes starting with 7, 8, or 9):
# 7012
# 7406
# 7429
# 7795
# 7813
# 7829
# 7899
# 8151
# 8152
# 8301
# 8304
# 8431
# 8714
# 8907
# 9008
# 9019
# 9035
# 9036
# 9241
# 9242
# 9341
# 9342
# 9343
# 9400
# 9448
# 9449
# 9526
# 9656
# 9738
# 9739
# 9740
# 9741
# 9742
# 9744
# 9844
# 9845
# 9900
# 9961
#
# Telemarketers' numbers start with the prefix 140:
# 1400481538
# 1401747654
# 1402316533
# 1403072432
# 1403579926
# 1404073047
# 1404368883
# 1404787681
# 1407539117
# 1408371942
# 1408409918
# 1408672243
# 1409421631
# 1409668775
# 1409994233
#
# PART B
# There were 605 fixed line to fixed line calls.
#
# There were 1804 outbound calls made from fixed lines.
#
# ...

# %%
# !python Task4.py
# Out:
# Altogether, there are 479<count> unique callers' and 497 unique receivers' telephone numbers in the records of calls.csv.
#  There are 250 unique texters' numbers (senders and receivers) in the records of texts.csv.
# The 479 unique callers' telephone numbers are (only first 5 numbers shown for brevity):
#
# ['(011)21017178', '(011)68486606', '(022)21884607', '(022)22288051', '(022)28765220']
#
# The 497 unique receivers' telephone numbers are (only first 5 numbers shown for brevity):
#
# ['(011)21017178', '(011)47486239', '(011)68486606', '(022)21884607', '(022)22288051']
#
# The 250 unique texters' telephone numbers are (only first 5 numbers shown for brevity):
#
# ['70121 27677', '70127 59322', '70129 62374', '74060 75431', '74066 31484']
#
#
# These 280 numbers could be telemarketers:
# Criteria: Numbers that make outgoing calls but never send texts, receive texts or receive incoming calls.
# (011)21017178
# (011)68486606
# (022)21884607
# (022)22288051
# (022)28765220
# ...
